# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc("font", size=15)

path = "../output/CA_GCN/single_bert-base-uncased_ts0.2_ml510_nc462_bs1_rs1_lr1e-05_hf512_['baseball']_scFalse_loss_info.csv"
df = pd.read_csv(path)

plt.figure(figsize=(12,8))
plt.plot(df["tr_loss"], label="tr. loss" )
plt.plot(df["vl_loss"], label="vl. loss")

plt.title(path.split("/")[-1])
plt.ylabel("Loss")
plt.xlabel("Epochs")

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # # Epochs

# %% [markdown]
# ## Columnwise

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc("font", size=15)

learning_rate = 1e-05
sport_domains = ["baseball","basketball","football","hockey","soccer"]


### GCN epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN/single_bert-base-uncased_ts0.2_ml510_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            try:
                print(f"No classification report for {sport_domain} with random state {random_state} with max length 510")
                df = pd.read_csv(f"../output/CA_GCN/single_bert-base-uncased_ts0.2_ml254_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
                data.append([sport_domain, random_state, len(df)])
            except:    
                print(f"GCN: No classification report for {sport_domain} with random state {random_state}")


df_gcn_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GCN_Conv1 eopchs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN_Conv1/single_bert-base-uncased_ts0.2_ml510_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            try:
                print(f"No classification report for {sport_domain} with random state {random_state} with max length 510")
                df = pd.read_csv(f"../output/CA_GCN_Conv1/single_bert-base-uncased_ts0.2_ml254_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
                data.append([sport_domain, random_state, len(df)])
            except:    
                print(f"GCN_COnv1: No classification report for {sport_domain} with random state {random_state}")


df_gcn_conv1_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GAT eopchs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GAT/single_bert-base-uncased_ts0.2_ml510_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            try:
                print(f"No classification report for {sport_domain} with random state {random_state} with max length 510")
                df = pd.read_csv(f"../output/CA_GAT/single_bert-base-uncased_ts0.2_ml254_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
                data.append([sport_domain, random_state, len(df)])
            except:    
                print(f"GAT: No classification report for {sport_domain} with random state {random_state}")


df_gat_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### Doduo epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"/ext/daten-wi/slangenecker/doduo/doduo/sven_tests/model/SportsTables_single_bert_bert-base-uncased-bs16-ml-510__SportsTables-1.00_scFalse_rs{random_state}_['{sport_domain}']_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            try:
                print(f"No classification report for {sport_domain} with random state {random_state} with max length 510")
                df = pd.read_csv(f"/ext/daten-wi/slangenecker/doduo/doduo/sven_tests/model/SportsTables_single_bert_bert-base-uncased-bs16-ml-254__SportsTables-1.00_scFalse_rs{random_state}_['{sport_domain}']_loss_info.csv")
                data.append([sport_domain, random_state, len(df)])
            except:    
                print(f"No classification report for {sport_domain} with random state {random_state}")


df_doduo_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

## Plot
fig, ax = plt.subplots(figsize=(20,10))

plt.title("Columnwise Serialization / #Training Epochs")
ax.plot(df_gcn_epochs["#epochs"], label="GCN", marker="o")
ax.plot(df_gcn_conv1_epochs["#epochs"], label="GCN Conv1", marker="o")
ax.plot(df_gat_epochs["#epochs"], label="GAT", marker="o")
ax.plot(df_doduo_epochs["#epochs"], label="Doduo", marker="o")

ax.set_ylabel("#Epochs")
ax.legend()
plt.show()
# Out:
# No classification report for football with random state 4 with max length 510
# No classification report for baseball with random state 1 with max length 510
# No classification report for baseball with random state 2 with max length 510
# No classification report for baseball with random state 3 with max length 510
# No classification report for baseball with random state 4 with max length 510
# No classification report for baseball with random state 5 with max length 510
# No classification report for basketball with random state 1 with max length 510
# No classification report for basketball with random state 2 with max length 510
# No classification report for basketball with random state 3 with max length 510
# No classification report for basketball with random state 4 with max length 510
# No classification report for basketball with random state 5 with max length 510
# No classification report for football with random state 1 with max length 510
# ...

# %% [markdown]
# ## Tablewise

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc("font", size=15)

learning_rate = 1e-05
sport_domains = ["baseball","basketball","football","hockey","soccer"]

### GCN epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")


df_gcn_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GCN epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN_Conv1/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")


df_gcn_conv1_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GAT epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GAT/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scFalse_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"GAT: No classification report for {sport_domain} with random state {random_state}")


df_gat_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### Doduo epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"/ext/daten-wi/slangenecker/doduo/doduo/sven_tests/model/SportsTables_mosato_bert_bert-base-uncased-bs1-ml-10__SportsTables-1.00_scFalse_rs{random_state}_['{sport_domain}']_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")

df_doduo_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

## Plot
fig, ax = plt.subplots(figsize=(20,10))

plt.title("Tablewise Serialization / #Training Epochs")

ax.plot(df_gcn_epochs["#epochs"], label="GCN", marker="o")
ax.plot(df_gcn_conv1_epochs["#epochs"], label="GCN Conv1", marker="o")
ax.plot(df_gat_epochs["#epochs"], label="GAT", marker="o")
ax.plot(df_doduo_epochs["#epochs"], label="Doduo", marker="o")

ax.set_ylabel("#Epochs")
ax.legend()
plt.show()
# Out:
# GAT: No classification report for baseball with random state 1
# GAT: No classification report for baseball with random state 2
# GAT: No classification report for baseball with random state 3
# GAT: No classification report for baseball with random state 4
# GAT: No classification report for baseball with random state 5
# GAT: No classification report for basketball with random state 1
# GAT: No classification report for basketball with random state 2
# GAT: No classification report for basketball with random state 3
# GAT: No classification report for basketball with random state 4
# GAT: No classification report for basketball with random state 5
# GAT: No classification report for football with random state 1
# GAT: No classification report for football with random state 2
# GAT: No classification report for football with random state 3
# GAT: No classification report for football with random state 4
# GAT: No classification report for football with random state 5
# ...

# %% [markdown]
# ## Tablewise shuffeld cols

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc("font", size=15)

learning_rate = 1e-05
sport_domains = ["baseball","basketball","football","hockey","soccer"]

### GCN epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scTrue_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")


df_gcn_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GCN Conv1 epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GCN_Conv1/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scTrue_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")


df_gcn_conv1_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### GAT epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"../output/CA_GAT/table_bert-base-uncased_ts0.2_ml10_nc462_bs1_rs{random_state}_lr{learning_rate}_hf512_['{sport_domain}']_scTrue_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")


df_gat_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

### Doduo epochs
data = []
for sport_domain in sport_domains:
    for random_state in range(1,6):
        try:
            df = pd.read_csv(f"/ext/daten-wi/slangenecker/doduo/doduo/sven_tests/model/SportsTables_mosato_bert_bert-base-uncased-bs1-ml-10__SportsTables-1.00_scTrue_rs{random_state}_['{sport_domain}']_loss_info.csv")
            data.append([sport_domain, random_state, len(df)])
        except:
            print(f"No classification report for {sport_domain} with random state {random_state}")

df_doduo_epochs = pd.DataFrame(data, columns=["sport_domain", "random_state", "#epochs"])

## Plot
fig, ax = plt.subplots(figsize=(20,10))

plt.title("Tablewise Serialization (shuffeld columns) / #Training Epochs")
ax.plot(df_gcn_epochs["#epochs"], label="GCN", marker="o")
ax.plot(df_gcn_conv1_epochs["#epochs"], label="GCN Conv1", marker="o")
ax.plot(df_gat_epochs["#epochs"], label="GAT", marker="o")
ax.plot(df_doduo_epochs["#epochs"], label="Doduo", marker="o")

ax.set_ylabel("#Epochs")
ax.legend()
plt.show()

# %%
df_gcn_epochs
# Out:
#    sport_domain  random_state  #epochs
# 0      baseball             1        0
# 1      baseball             2        0
# 2      baseball             3        0
# 3      baseball             4        0
# 4      baseball             5        0
# 5    basketball             1        0
# 6    basketball             2        0
# 7    basketball             3        0
# 8    basketball             4        0
# 9    basketball             5        0
# 10     football             1        0
# 11     football             2        0
# 12     football             3        0
# 13     football             4        0
# 14     football             5        0
# 15       hockey             1        0
# 16       hockey             2        0
# 17       hockey             3        0
# 18       hockey             4        0
# 19       hockey             5        0
# 20       soccer             1        0
# 21       soccer             2        0
# 22       soccer             3        0
# ...
